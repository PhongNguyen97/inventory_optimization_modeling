# %%
import pandas as pd

# %%
base_case_opt_results = pd.read_csv("../outputs/policy_results/base_case_optimization_results.csv")
base_case_opt_results
# Out:
#       family policy_type   safety_stock  reorder_point  order_quantity  \
# 0  GROCERY I       (s,Q)  487622.562927   1.750781e+06   314433.578236
# 1  BEVERAGES       (s,Q)  588068.725480   1.565681e+06   260348.018483
# 2   CLEANING       (R,S)       0.000000            NaN             NaN
#
#    order_up_to_level  fill_rate  cycle_service_level     total_cost  \
# 0                NaN   0.991579             0.931267  543439.884926
# 1                NaN   0.996574             0.984700  156552.765627
# 2      798371.817225   1.000000             1.000000    1361.653599
#
#    avg_inventory  num_orders   units_short  gamma_benchmark_safety_stock
# 0  609857.946773         3.0  36107.045287                 486101.043089
# 1  687134.048563         3.0  12874.637348                 691113.626070
# 2  446039.914304         3.0      0.000000                  83818.182746

# %%
final_policy_results = pd.read_csv("../outputs/policy_results/final_policy_results.csv")
final_policy_results
# Out:
#       family policy_type   safety_stock  reorder_point  order_quantity  \
# 0  GROCERY I       (s,Q)  487622.562927   1.750781e+06   314433.578236
# 1  BEVERAGES       (s,Q)  588068.725480   1.565681e+06   260348.018483
# 2   CLEANING       (R,S)       0.000000            NaN             NaN
#
#    order_up_to_level  fill_rate  cycle_service_level     total_cost  \
# 0                NaN   0.991579             0.931267  543439.884926
# 1                NaN   0.996574             0.984700  156552.765627
# 2      798371.817225   1.000000             1.000000    1361.653599
#
#    avg_inventory  num_orders   units_short  gamma_benchmark_safety_stock
# 0  609857.946773         3.0  36107.045287                 486101.043089
# 1  687134.048563         3.0  12874.637348                 691113.626070
# 2  446039.914304         3.0      0.000000                  83818.182746

# %%
sensitivity_summary = pd.read_csv("../outputs/sensitivity_results/sensitivity_summary.csv")
sensitivity_summary
# Out:
#    policy_type  safety_stock  reorder_point  order_quantity  \
# 0        (s,Q)  4.876226e+05   1.750781e+06   314433.578236
# 1        (s,Q)  4.876226e+05   1.750781e+06   317141.927807
# 2        (s,Q)  4.876226e+05   1.750781e+06   236395.696446
# 3        (s,Q)  4.876226e+05   1.750781e+06   193016.277894
# 4        (s,Q)  4.876226e+05   1.750781e+06   444676.230806
# 5        (s,Q)  4.876226e+05   1.750781e+06   314433.578236
# 6        (s,Q)  4.876226e+05   1.750781e+06   314433.578236
# 7        (s,Q)  5.880687e+05   1.565681e+06   260348.018483
# 8        (s,Q)  5.880687e+05   1.565681e+06   259073.669086
# 9        (s,Q)  5.880687e+05   1.565681e+06   207966.730084
# 10       (s,Q)  5.880687e+05   1.565681e+06   169804.124060
# 11       (s,Q)  5.880687e+05   1.565681e+06   391199.429842
# 12       (s,Q)  5.880687e+05   1.565681e+06   260348.018483
# 13       (s,Q)  5.880687e+05   1.565681e+06   260348.018483
# 14       (R,S)  0.000000e+00            NaN             NaN
# ...

# %% [markdown]
# ![sensitivity_cost_summary_grocery_i](../outputs/plots/sensitivity_cost_summary_grocery_i.png)

# %% [markdown]
# ![sensitivity_cost_summary_grocery_i](../outputs/plots/sensitivity_cost_summary_beverages.png)

# %% [markdown]
# ![sensitivity_cost_summary_grocery_i](../outputs/plots/sensitivity_cost_summary_cleaning.png)

# %%
policy_justfication_statistics = pd.read_csv("../outputs/tables/policy_justification_statistics.csv")
policy_justfication_statistics
# Out:
#       family  Mean Weekly Demand  Weekly Standard Deviation  Weekly CV  \
# 0  BEVERAGES        9.461241e+05              381694.896193   0.403430
# 1   CLEANING        4.155624e+05               73498.654089   0.176865
# 2  GROCERY I        1.476838e+06              333585.520786   0.225878
#
#    Weekly Demand Frequency  Weekly Zero-Demand Frequency Chosen Policy
# 0                      1.0                           0.0            SQ
# 1                      1.0                           0.0            RS
# 2                      1.0                           0.0            SQ

# %%
powerbi_inventory_policy_table = pd.read_csv("../outputs/tables/powerbi_inventory_policy_table.csv")
powerbi_inventory_policy_table
# Out:
#       family policy_type  lead_time  review_period  risk_period  safety_stock  \
# 0  GROCERY I       (s,Q)          1            NaN            1   487622.5629
# 1  BEVERAGES       (s,Q)          1            NaN            1   588068.7255
# 2   CLEANING       (R,S)          1            1.0            2        0.0000
#
#    reorder_point  order_quantity  order_up_to_level  fill_rate  \
# 0   1.750781e+06     314433.5782                NaN     0.9916
# 1   1.565681e+06     260348.0185                NaN     0.9966
# 2            NaN             NaN        798371.8172     1.0000
#
#    cycle_service_level   total_cost  avg_inventory  num_orders  units_short
# 0               0.9313  543439.8849    609857.9468         3.0   36107.0453
# 1               0.9847  156552.7656    687134.0486         3.0   12874.6373
# 2               1.0000    1361.6536    446039.9143         3.0       0.0000

# %% [markdown]
# ![sensitivity_cost_summary_grocery_i](../outputs/plots/ending_inventory_dist_grocery_i.png)

# %% [markdown]
# ![sensitivity_cost_summary_grocery_i](../outputs/plots/ending_inventory_dist_beverages.png)

# %% [markdown]
# ![sensitivity_cost_summary_grocery_i](../outputs/plots/ending_inventory_dist_cleaning.png)
